# %%
import pandas as pd
import re

# Cargar el archivo Excel para analizar su contenido
file_path = '..\Excels\logs-exam.xlsx'
xls = pd.ExcelFile(file_path)

# Mostrar las hojas del archivo
sheet_names = xls.sheet_names
sheet_names
# Out:
# ['Sheet1']

# %%
# Cargar la hoja 'Sheet1' para analizar las primeras filas
df = pd.read_excel(file_path, sheet_name='Sheet1')

# Mostrar las primeras filas del DataFrame para revisar la estructura
df.head()
# Out:
#                  Hora Nombre completo del usuario Usuario afectado  \
# 0  13/10/24, 14:06:30             Anderson Molina                -
# 1  13/10/24, 14:06:17             Anderson Molina                -
# 2  13/10/24, 14:06:08             Anderson Molina                -
# 3  11/10/24, 11:18:43           Geraldine Tasayco                -
# 4  11/10/24, 00:07:57              Patricia Avila   Patricia Avila
#
#                                  Contexto del evento Componente  \
# 0  Examen: Examen para LRPD: Estadística y Probab...     Examen
# 1  Examen: Examen para LRPD: Estadística y Probab...     Examen
# 2  Examen: Examen para LRPD: Estadística y Probab...     Examen
# 3  Examen: Examen para LRPD: Estadística y Probab...     Examen
# 4  Examen: Examen para LRPD: Estadística y Probab...     Examen
#
#             Nombre del evento  \
# 0     Reporte de examen visto
# 1     Reporte de examen visto
# 2       Módulo de curso visto
# 3       Módulo de curso visto
# 4  Intento de examen revisado
#
#                                          Descripción Origen     Dirección IP
# 0  The user with id '2' viewed the report 'overvi...    web    38.250.154.25
# 1  The user with id '2' viewed the report 'overvi...    web    38.250.154.25
# 2  The user with id '2' viewed the 'quiz' activit...    web    38.250.154.25
# 3  The user with id '52' viewed the 'quiz' activi...    web   181.224.237.26
# 4  The user with id '28' has reviewed quiz attemp...    web  190.234.141.205

# %%
# Función para extraer el ID de usuario del campo 'Descripción'
def extract_user_id(description):
    match = re.search(r"The user with id '(\d+)'", description)
    if match:
        return int(match.group(1))
    return None

# Crear una nueva columna con el ID extraído
df['User ID'] = df['Descripción'].apply(extract_user_id)

# Mostrar las primeras filas con la nueva columna
df[['User ID']].head()

df
# Out:
#                     Hora Nombre completo del usuario Usuario afectado  \
# 0     13/10/24, 14:06:30             Anderson Molina                -
# 1     13/10/24, 14:06:17             Anderson Molina                -
# 2     13/10/24, 14:06:08             Anderson Molina                -
# 3     11/10/24, 11:18:43           Geraldine Tasayco                -
# 4     11/10/24, 00:07:57              Patricia Avila   Patricia Avila
# ...                  ...                         ...              ...
# 1662   9/09/24, 13:39:42             Anderson Molina                -
# 1663   9/09/24, 13:37:12             Anderson Molina                -
# 1664   9/09/24, 13:33:36             Anderson Molina                -
# 1665   9/09/24, 13:33:20             Anderson Molina                -
# 1666   9/09/24, 13:33:20             Anderson Molina                -
#
#                                     Contexto del evento Componente  \
# 0     Examen: Examen para LRPD: Estadística y Probab...     Examen
# 1     Examen: Examen para LRPD: Estadística y Probab...     Examen
# 2     Examen: Examen para LRPD: Estadística y Probab...     Examen
# 3     Examen: Examen para LRPD: Estadística y Probab...     Examen
# 4     Examen: Examen para LRPD: Estadística y Probab...     Examen
# ...                                                 ...        ...
# 1662  Examen: Examen para LRPD: Estadística y Probab...     Examen
# 1663  Examen: Examen para LRPD: Estadística y Probab...     Examen
# 1664  Examen: Examen para LRPD: Estadística y Probab...     Examen
# 1665  Examen: Examen para LRPD: Estadística y Probab...     Examen
# 1666  Examen: Examen para LRPD: Estadística y Probab...    Sistema
#
#                       Nombre del evento  \
# 0               Reporte de examen visto
# 1               Reporte de examen visto
# 2                 Módulo de curso visto
# 3                 Módulo de curso visto
# 4            Intento de examen revisado
# ...                                 ...
# 1662                    Posición creada
# 1663  Página de edición de examen vista
# 1664  Página de edición de examen vista
# 1665              Módulo de curso visto
# 1666             Módulo de curso creado
#
#                                             Descripción Origen  \
# 0     The user with id '2' viewed the report 'overvi...    web
# 1     The user with id '2' viewed the report 'overvi...    web
# 2     The user with id '2' viewed the 'quiz' activit...    web
# 3     The user with id '52' viewed the 'quiz' activi...    web
# 4     The user with id '28' has reviewed quiz attemp...    web
# ...                                                 ...    ...
# 1662  The user with id '2' created a new slot with i...    web
# 1663  The user with id '2' viewed the edit page for ...    web
# 1664  The user with id '2' viewed the edit page for ...    web
# 1665  The user with id '2' viewed the 'quiz' activit...    web
# 1666  The user with id '2' created the 'quiz' activi...    web
#
#          Dirección IP  User ID
# 0       38.250.154.25        2
# 1       38.250.154.25        2
# 2       38.250.154.25        2
# 3      181.224.237.26       52
# 4     190.234.141.205       28
# ...               ...      ...
# 1662     38.250.154.7        2
# 1663     38.250.154.7        2
# 1664     38.250.154.7        2
# 1665     38.250.154.7        2
# 1666     38.250.154.7        2
#
# [1667 rows x 10 columns]
